# %%
import os

# Set your image folder path
folder_path = r'D:/PhilSA/OpERA/_FieldExtraction/scripts/photos/benthic/val/seagrass'  # Change this

# List all jpg files
image_files = [f for f in os.listdir(folder_path) if f.lower().endswith('.jpg')]

# Sort files (optional, depends on your preference)
image_files.sort()

# Rename files
for idx, filename in enumerate(image_files, start=1):
    new_name = f'seagrass.{idx}.jpg'
    src = os.path.join(folder_path, filename)
    dst = os.path.join(folder_path, new_name)
    os.rename(src, dst)
    print(f'Renamed: {filename} -> {new_name}')
# Out:
# Renamed: frame_2025-05-14_08-50-27.jpg -> seagrass.1.jpg
# Renamed: frame_2025-05-14_08-50-35.jpg -> seagrass.2.jpg
# Renamed: frame_2025-05-14_08-50-36.jpg -> seagrass.3.jpg
# Renamed: frame_2025-05-14_08-50-48.jpg -> seagrass.4.jpg
# Renamed: frame_2025-05-14_08-50-49.jpg -> seagrass.5.jpg
# Renamed: frame_2025-05-14_08-50-50.jpg -> seagrass.6.jpg
# Renamed: frame_2025-05-14_08-50-56.jpg -> seagrass.7.jpg
# Renamed: frame_2025-05-14_08-51-00.jpg -> seagrass.8.jpg
# Renamed: frame_2025-05-14_08-51-02.jpg -> seagrass.9.jpg
# Renamed: frame_2025-05-14_08-51-08.jpg -> seagrass.10.jpg
